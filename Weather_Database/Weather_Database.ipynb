# %%
#Create set of 2000 random latitudes and longitudes.

#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from datetime import datetime

# Import the API key.
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats2 = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs2 = np.random.uniform(low=-180.000, high=180.000, size=2000)
#Pair up lat and lng values and make zip object
lat_lngs2 = zip(lats2, lngs2)
lat_lngs2

# %%
# Add the latitudes and longitudes to a list.
coord = list(lat_lngs2)

# %%
# Create a list for holding the cities.
cities2 = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coord:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities2:
        cities2.append(city)
# Print the city count to confirm sufficient count.
len(cities2)
# Out:
# 763

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities2):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

#Run API request for each city
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descrip,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 2 of Set 1 | along
# Processing Record 3 of Set 1 | tabory
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | avera
# Processing Record 7 of Set 1 | kathmandu
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | skjervoy
# Processing Record 10 of Set 1 | moree
# Processing Record 11 of Set 1 | corinto
# Processing Record 12 of Set 1 | cuauhtemoc
# Processing Record 13 of Set 1 | torbay
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | san quintin
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | lagoa
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | airai
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | cidreira
# Processing Record 26 of Set 1 | tiksi
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 30 of Set 1 | olinda
# Processing Record 31 of Set 1 | severo-kurilsk
# Processing Record 32 of Set 1 | apa
# Processing Record 33 of Set 1 | ushuaia
# Processing Record 34 of Set 1 | guanica
# Processing Record 35 of Set 1 | saint-philippe
# Processing Record 36 of Set 1 | caucaia
# Processing Record 37 of Set 1 | taoudenni
# Processing Record 38 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 1 | bocas del toro
# Processing Record 40 of Set 1 | silifke
# Processing Record 41 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 42 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | ulladulla
# Processing Record 46 of Set 1 | iranshahr
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | carnarvon
# Processing Record 1 of Set 2 | belaya gora
# Processing Record 2 of Set 2 | uray
# Processing Record 3 of Set 2 | comodoro rivadavia
# Processing Record 4 of Set 2 | tasiilaq
# Processing Record 5 of Set 2 | port alfred
# Processing Record 6 of Set 2 | hermanus
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | lompoc
# Processing Record 10 of Set 2 | ahuimanu
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | qaanaaq
# Processing Record 13 of Set 2 | cape town
# Processing Record 14 of Set 2 | kapaa
# Processing Record 15 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 2 | solsvik
# City not found. Skipping...
# Processing Record 17 of Set 2 | tara
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | torrijos
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | najran
# Processing Record 22 of Set 2 | ribeira grande
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | college
# Processing Record 25 of Set 2 | zhangjiakou
# Processing Record 26 of Set 2 | namatanai
# Processing Record 27 of Set 2 | kholm
# Processing Record 28 of Set 2 | klyuchevskiy
# Processing Record 29 of Set 2 | rumonge
# Processing Record 30 of Set 2 | leningradskiy
# Processing Record 31 of Set 2 | palauig
# Processing Record 32 of Set 2 | saint-joseph
# Processing Record 33 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 34 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 35 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 36 of Set 2 | aipe
# Processing Record 37 of Set 2 | pevek
# Processing Record 38 of Set 2 | usogorsk
# Processing Record 39 of Set 2 | shingu
# Processing Record 40 of Set 2 | praia da vitoria
# Processing Record 41 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | faanui
# Processing Record 44 of Set 2 | kahului
# Processing Record 45 of Set 2 | hilo
# Processing Record 46 of Set 2 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | celestun
# Processing Record 49 of Set 2 | isangel
# Processing Record 50 of Set 2 | saldanha
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | touros
# Processing Record 3 of Set 3 | ballina
# Processing Record 4 of Set 3 | eyl
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | flagstaff
# Processing Record 7 of Set 3 | mitsamiouli
# Processing Record 8 of Set 3 | vaini
# Processing Record 9 of Set 3 | barcelona
# Processing Record 10 of Set 3 | nago
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | tuatapere
# Processing Record 13 of Set 3 | jacksonville
# Processing Record 14 of Set 3 | chokurdakh
# Processing Record 15 of Set 3 | norman wells
# Processing Record 16 of Set 3 | tiznit
# Processing Record 17 of Set 3 | laguna
# Processing Record 18 of Set 3 | saskylakh
# Processing Record 19 of Set 3 | vryburg
# Processing Record 20 of Set 3 | banda
# Processing Record 21 of Set 3 | tura
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | tomatlan
# Processing Record 24 of Set 3 | nyrob
# Processing Record 25 of Set 3 | farafangana
# Processing Record 26 of Set 3 | port hardy
# Processing Record 27 of Set 3 | rotifunk
# Processing Record 28 of Set 3 | akyab
# Processing Record 29 of Set 3 | bethel
# Processing Record 30 of Set 3 | meulaboh
# Processing Record 31 of Set 3 | bati
# Processing Record 32 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 33 of Set 3 | aksu
# Processing Record 34 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 35 of Set 3 | tanggu
# Processing Record 36 of Set 3 | agirish
# Processing Record 37 of Set 3 | nanakuli
# Processing Record 38 of Set 3 | yellowknife
# Processing Record 39 of Set 3 | anadyr
# Processing Record 40 of Set 3 | kavaratti
# Processing Record 41 of Set 3 | shanghai
# Processing Record 42 of Set 3 | provideniya
# Processing Record 43 of Set 3 | mpika
# Processing Record 44 of Set 3 | adana
# Processing Record 45 of Set 3 | ukiah
# Processing Record 46 of Set 3 | progreso
# Processing Record 47 of Set 3 | deputatskiy
# Processing Record 48 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 49 of Set 3 | hithadhoo
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | narsaq
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | creel
# Processing Record 4 of Set 4 | grindavik
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | salinopolis
# Processing Record 7 of Set 4 | burkhala
# City not found. Skipping...
# Processing Record 8 of Set 4 | hervey bay
# Processing Record 9 of Set 4 | nanortalik
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | la primavera
# Processing Record 12 of Set 4 | ferrol
# Processing Record 13 of Set 4 | novoagansk
# Processing Record 14 of Set 4 | hasaki
# Processing Record 15 of Set 4 | kassala
# Processing Record 16 of Set 4 | kenai
# Processing Record 17 of Set 4 | sheffield
# Processing Record 18 of Set 4 | paamiut
# Processing Record 19 of Set 4 | luena
# Processing Record 20 of Set 4 | mayskiy
# Processing Record 21 of Set 4 | egvekinot
# Processing Record 22 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 4 | nizwa
# Processing Record 24 of Set 4 | lasa
# Processing Record 25 of Set 4 | fortuna
# Processing Record 26 of Set 4 | lebu
# Processing Record 27 of Set 4 | saint-augustin
# Processing Record 28 of Set 4 | santa maria
# Processing Record 29 of Set 4 | cururupu
# Processing Record 30 of Set 4 | yulara
# Processing Record 31 of Set 4 | moerai
# Processing Record 32 of Set 4 | fairbanks
# Processing Record 33 of Set 4 | akureyri
# Processing Record 34 of Set 4 | bathsheba
# Processing Record 35 of Set 4 | ust-nera
# Processing Record 36 of Set 4 | padang
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | uniao
# Processing Record 39 of Set 4 | achacachi
# Processing Record 40 of Set 4 | khasan
# Processing Record 41 of Set 4 | khatanga
# Processing Record 42 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 4 | batagay-alyta
# Processing Record 44 of Set 4 | sindor
# Processing Record 45 of Set 4 | dubai
# Processing Record 46 of Set 4 | camacha
# Processing Record 47 of Set 4 | khorramshahr
# Processing Record 48 of Set 4 | sao filipe
# Processing Record 49 of Set 4 | matagami
# Processing Record 50 of Set 4 | geraldton
# Processing Record 1 of Set 5 | nador
# Processing Record 2 of Set 5 | aksehir
# Processing Record 3 of Set 5 | estepa
# Processing Record 4 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 5 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 5 | wucheng
# Processing Record 7 of Set 5 | carballo
# Processing Record 8 of Set 5 | pacific grove
# Processing Record 9 of Set 5 | acajutla
# Processing Record 10 of Set 5 | soyo
# Processing Record 11 of Set 5 | lazaro cardenas
# Processing Record 12 of Set 5 | zhangye
# Processing Record 13 of Set 5 | savelugu
# Processing Record 14 of Set 5 | hofn
# Processing Record 15 of Set 5 | poum
# Processing Record 16 of Set 5 | puro
# Processing Record 17 of Set 5 | marawi
# Processing Record 18 of Set 5 | carutapera
# Processing Record 19 of Set 5 | hirara
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | palaiokhora
# City not found. Skipping...
# Processing Record 22 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 23 of Set 5 | codrington
# Processing Record 24 of Set 5 | san cristobal
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 27 of Set 5 | basavana bagevadi
# Processing Record 28 of Set 5 | ilulissat
# Processing Record 29 of Set 5 | iskateley
# Processing Record 30 of Set 5 | nabul
# City not found. Skipping...
# Processing Record 31 of Set 5 | mattawa
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | homer
# Processing Record 34 of Set 5 | kodiak
# Processing Record 35 of Set 5 | griffith
# Processing Record 36 of Set 5 | sorong
# Processing Record 37 of Set 5 | klaksvik
# Processing Record 38 of Set 5 | samana
# Processing Record 39 of Set 5 | san policarpo
# Processing Record 40 of Set 5 | katsuura
# Processing Record 41 of Set 5 | gavrilovka vtoraya
# Processing Record 42 of Set 5 | puerto escondido
# Processing Record 43 of Set 5 | akalgarh
# Processing Record 44 of Set 5 | castro
# Processing Record 45 of Set 5 | kulhudhuffushi
# Processing Record 46 of Set 5 | nome
# Processing Record 47 of Set 5 | qianan
# Processing Record 48 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 5 | billings
# Processing Record 50 of Set 5 | kollam
# Processing Record 1 of Set 6 | saint-georges
# Processing Record 2 of Set 6 | vostok
# Processing Record 3 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 4 of Set 6 | la orilla
# Processing Record 5 of Set 6 | champaign
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | lipin bor
# Processing Record 8 of Set 6 | alice springs
# Processing Record 9 of Set 6 | tanete
# Processing Record 10 of Set 6 | udachnyy
# Processing Record 11 of Set 6 | siavonga
# Processing Record 12 of Set 6 | komsomolskiy
# Processing Record 13 of Set 6 | richards bay
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | rafai
# Processing Record 16 of Set 6 | salalah
# Processing Record 17 of Set 6 | mori
# Processing Record 18 of Set 6 | butaritari
# Processing Record 19 of Set 6 | porangatu
# Processing Record 20 of Set 6 | zaysan
# Processing Record 21 of Set 6 | filadelfia
# Processing Record 22 of Set 6 | kaitangata
# Processing Record 23 of Set 6 | alihe
# Processing Record 24 of Set 6 | rorvik
# Processing Record 25 of Set 6 | matara
# Processing Record 26 of Set 6 | iqaluit
# Processing Record 27 of Set 6 | sola
# Processing Record 28 of Set 6 | awbari
# Processing Record 29 of Set 6 | vastseliina
# Processing Record 30 of Set 6 | whitianga
# Processing Record 31 of Set 6 | pasighat
# Processing Record 32 of Set 6 | mizpe ramon
# City not found. Skipping...
# Processing Record 33 of Set 6 | imeni zhelyabova
# Processing Record 34 of Set 6 | taylorville
# Processing Record 35 of Set 6 | katobu
# Processing Record 36 of Set 6 | chara
# Processing Record 37 of Set 6 | gat
# Processing Record 38 of Set 6 | ust-uda
# Processing Record 39 of Set 6 | flinders
# Processing Record 40 of Set 6 | antalaha
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | petropavl
# Processing Record 43 of Set 6 | nuevitas
# Processing Record 44 of Set 6 | gold coast
# Processing Record 45 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 6 | tambopata
# Processing Record 47 of Set 6 | muisne
# Processing Record 48 of Set 6 | springbok
# Processing Record 49 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 6 | vardo
# Processing Record 1 of Set 7 | vestmannaeyjar
# Processing Record 2 of Set 7 | dawson creek
# Processing Record 3 of Set 7 | roald
# Processing Record 4 of Set 7 | port macquarie
# Processing Record 5 of Set 7 | los llanos de aridane
# Processing Record 6 of Set 7 | nouakchott
# Processing Record 7 of Set 7 | broome
# Processing Record 8 of Set 7 | newport
# Processing Record 9 of Set 7 | namie
# Processing Record 10 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 7 | maniitsoq
# Processing Record 12 of Set 7 | sept-iles
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | banamba
# Processing Record 15 of Set 7 | brigantine
# Processing Record 16 of Set 7 | aykhal
# Processing Record 17 of Set 7 | pathein
# Processing Record 18 of Set 7 | nanjing
# Processing Record 19 of Set 7 | roma
# Processing Record 20 of Set 7 | waipawa
# Processing Record 21 of Set 7 | santiago del estero
# Processing Record 22 of Set 7 | shahrud
# Processing Record 23 of Set 7 | ucluelet
# Processing Record 24 of Set 7 | upington
# Processing Record 25 of Set 7 | volchikha
# Processing Record 26 of Set 7 | marrakesh
# Processing Record 27 of Set 7 | margate
# Processing Record 28 of Set 7 | sitka
# Processing Record 29 of Set 7 | yar-sale
# Processing Record 30 of Set 7 | lavrentiya
# Processing Record 31 of Set 7 | arman
# Processing Record 32 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 7 | chiredzi
# Processing Record 34 of Set 7 | phrai bung
# City not found. Skipping...
# Processing Record 35 of Set 7 | biak
# Processing Record 36 of Set 7 | rincon
# Processing Record 37 of Set 7 | gurskoye
# City not found. Skipping...
# Processing Record 38 of Set 7 | salto del guaira
# Processing Record 39 of Set 7 | luanda
# Processing Record 40 of Set 7 | zyryanka
# Processing Record 41 of Set 7 | hualmay
# Processing Record 42 of Set 7 | sechura
# Processing Record 43 of Set 7 | sheregesh
# Processing Record 44 of Set 7 | teguise
# Processing Record 45 of Set 7 | sayaxche
# Processing Record 46 of Set 7 | waddan
# Processing Record 47 of Set 7 | reitz
# Processing Record 48 of Set 7 | cranbourne
# Processing Record 49 of Set 7 | kieta
# Processing Record 50 of Set 7 | lufilufi
# Processing Record 1 of Set 8 | zapolyarnyy
# Processing Record 2 of Set 8 | opuwo
# Processing Record 3 of Set 8 | talawdi
# City not found. Skipping...
# Processing Record 4 of Set 8 | barreirinhas
# Processing Record 5 of Set 8 | manama
# Processing Record 6 of Set 8 | dingle
# Processing Record 7 of Set 8 | pitogo
# Processing Record 8 of Set 8 | kimparana
# Processing Record 9 of Set 8 | ostrovnoy
# Processing Record 10 of Set 8 | rawson
# Processing Record 11 of Set 8 | mahina
# Processing Record 12 of Set 8 | buala
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | kismayo
# Processing Record 15 of Set 8 | otjimbingwe
# Processing Record 16 of Set 8 | palana
# Processing Record 17 of Set 8 | zabol
# Processing Record 18 of Set 8 | voyvozh
# Processing Record 19 of Set 8 | kinkala
# Processing Record 20 of Set 8 | oberwart
# Processing Record 21 of Set 8 | podporozhye
# Processing Record 22 of Set 8 | karymskoye
# Processing Record 23 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 8 | kazerun
# Processing Record 25 of Set 8 | deh rawud
# City not found. Skipping...
# Processing Record 26 of Set 8 | buraydah
# Processing Record 27 of Set 8 | loanda
# Processing Record 28 of Set 8 | walvis bay
# Processing Record 29 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 30 of Set 8 | ozernovskiy
# Processing Record 31 of Set 8 | stokmarknes
# Processing Record 32 of Set 8 | xichang
# Processing Record 33 of Set 8 | luderitz
# Processing Record 34 of Set 8 | manicore
# Processing Record 35 of Set 8 | vanimo
# Processing Record 36 of Set 8 | morondava
# Processing Record 37 of Set 8 | union
# Processing Record 38 of Set 8 | mehran
# Processing Record 39 of Set 8 | yinchuan
# Processing Record 40 of Set 8 | barcelos
# Processing Record 41 of Set 8 | malatya
# Processing Record 42 of Set 8 | pangnirtung
# Processing Record 43 of Set 8 | bandarbeyla
# Processing Record 44 of Set 8 | ola
# Processing Record 45 of Set 8 | victoria
# Processing Record 46 of Set 8 | oranjestad
# Processing Record 47 of Set 8 | henties bay
# Processing Record 48 of Set 8 | pochutla
# Processing Record 49 of Set 8 | banjar
# Processing Record 50 of Set 8 | porto franco
# Processing Record 1 of Set 9 | kushima
# Processing Record 2 of Set 9 | auki
# Processing Record 3 of Set 9 | damaturu
# Processing Record 4 of Set 9 | pisco
# Processing Record 5 of Set 9 | pastos bons
# Processing Record 6 of Set 9 | san felipe
# Processing Record 7 of Set 9 | teguldet
# Processing Record 8 of Set 9 | san patricio
# Processing Record 9 of Set 9 | shangzhi
# Processing Record 10 of Set 9 | alofi
# Processing Record 11 of Set 9 | trinidad
# Processing Record 12 of Set 9 | russell
# Processing Record 13 of Set 9 | quatre cocos
# Processing Record 14 of Set 9 | mandal
# Processing Record 15 of Set 9 | shirokiy
# Processing Record 16 of Set 9 | acapulco
# Processing Record 17 of Set 9 | arauca
# Processing Record 18 of Set 9 | bambanglipuro
# Processing Record 19 of Set 9 | korla
# Processing Record 20 of Set 9 | potosi
# Processing Record 21 of Set 9 | mayumba
# Processing Record 22 of Set 9 | kijang
# Processing Record 23 of Set 9 | longhua
# Processing Record 24 of Set 9 | srednekolymsk
# Processing Record 25 of Set 9 | husavik
# Processing Record 26 of Set 9 | bobcaygeon
# Processing Record 27 of Set 9 | ivdel
# Processing Record 28 of Set 9 | saquarema
# Processing Record 29 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 9 | alberton
# Processing Record 31 of Set 9 | derzhavinsk
# Processing Record 32 of Set 9 | dourados
# Processing Record 33 of Set 9 | constantine
# Processing Record 34 of Set 9 | san jeronimo
# Processing Record 35 of Set 9 | mehamn
# Processing Record 36 of Set 9 | chkalovskoye
# Processing Record 37 of Set 9 | boa vista
# Processing Record 38 of Set 9 | chuy
# Processing Record 39 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 40 of Set 9 | ciudad bolivar
# Processing Record 41 of Set 9 | helong
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | debre tabor
# Processing Record 44 of Set 9 | tautira
# Processing Record 45 of Set 9 | pedasi
# Processing Record 46 of Set 9 | valverde del camino
# Processing Record 47 of Set 9 | karakol
# Processing Record 48 of Set 9 | hauterive
# Processing Record 49 of Set 9 | talnakh
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | siverek
# Processing Record 2 of Set 10 | san jose
# Processing Record 3 of Set 10 | myitkyina
# Processing Record 4 of Set 10 | keti bandar
# Processing Record 5 of Set 10 | marsabit
# Processing Record 6 of Set 10 | amboasary
# Processing Record 7 of Set 10 | fort-shevchenko
# Processing Record 8 of Set 10 | nsanje
# Processing Record 9 of Set 10 | bac lieu
# Processing Record 10 of Set 10 | aberdeen
# Processing Record 11 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 10 | ancud
# Processing Record 13 of Set 10 | baoding
# Processing Record 14 of Set 10 | cherskiy
# Processing Record 15 of Set 10 | north bend
# Processing Record 16 of Set 10 | tvoroyri
# Processing Record 17 of Set 10 | zhigansk
# Processing Record 18 of Set 10 | seoul
# Processing Record 19 of Set 10 | ourem
# Processing Record 20 of Set 10 | atar
# Processing Record 21 of Set 10 | oia
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | san rafael
# Processing Record 24 of Set 10 | saint anthony
# Processing Record 25 of Set 10 | saint-louis
# Processing Record 26 of Set 10 | clyde river
# Processing Record 27 of Set 10 | usinsk
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | waingapu
# Processing Record 30 of Set 10 | villa carlos paz
# Processing Record 31 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 10 | taunggyi
# Processing Record 33 of Set 10 | vila velha
# Processing Record 34 of Set 10 | quixere
# Processing Record 35 of Set 10 | qaqortoq
# Processing Record 36 of Set 10 | port blair
# Processing Record 37 of Set 10 | mackay
# Processing Record 38 of Set 10 | naze
# Processing Record 39 of Set 10 | sakakah
# Processing Record 40 of Set 10 | george
# Processing Record 41 of Set 10 | caravelas
# Processing Record 42 of Set 10 | bokoro
# Processing Record 43 of Set 10 | sanmenxia
# Processing Record 44 of Set 10 | kon tum
# Processing Record 45 of Set 10 | taltal
# Processing Record 46 of Set 10 | labuan
# Processing Record 47 of Set 10 | samarai
# Processing Record 48 of Set 10 | half moon bay
# Processing Record 49 of Set 10 | belmonte
# Processing Record 50 of Set 10 | jonuta
# Processing Record 1 of Set 11 | chifeng
# Processing Record 2 of Set 11 | cotonou
# Processing Record 3 of Set 11 | panama city
# Processing Record 4 of Set 11 | kavieng
# Processing Record 5 of Set 11 | petrinja
# Processing Record 6 of Set 11 | georgiu-dezh
# City not found. Skipping...
# Processing Record 7 of Set 11 | abong mbang
# Processing Record 8 of Set 11 | cajamarca
# Processing Record 9 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 11 | sorland
# Processing Record 11 of Set 11 | kaupanger
# Processing Record 12 of Set 11 | ouadda
# Processing Record 13 of Set 11 | nuuk
# Processing Record 14 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 11 | portoviejo
# Processing Record 16 of Set 11 | port-cartier
# Processing Record 17 of Set 11 | laramie
# Processing Record 18 of Set 11 | esmeralda
# Processing Record 19 of Set 11 | barbacoas
# Processing Record 20 of Set 11 | constitucion
# Processing Record 21 of Set 11 | tempio pausania
# Processing Record 22 of Set 11 | moron
# Processing Record 23 of Set 11 | abu samrah
# Processing Record 24 of Set 11 | vanavara
# Processing Record 25 of Set 11 | robinson
# Processing Record 26 of Set 11 | bentiu
# Processing Record 27 of Set 11 | shuya
# Processing Record 28 of Set 11 | terra santa
# Processing Record 29 of Set 11 | cabo rojo
# Processing Record 30 of Set 11 | seminole
# Processing Record 31 of Set 11 | kalmunai
# Processing Record 32 of Set 11 | smithers
# Processing Record 33 of Set 11 | grand-lahou
# Processing Record 34 of Set 11 | zhaotong
# Processing Record 35 of Set 11 | amuntai
# Processing Record 36 of Set 11 | midland
# Processing Record 37 of Set 11 | prescott
# Processing Record 38 of Set 11 | nizhnyaya poyma
# Processing Record 39 of Set 11 | gizo
# Processing Record 40 of Set 11 | qingdao
# Processing Record 41 of Set 11 | kirakira
# Processing Record 42 of Set 11 | fort nelson
# Processing Record 43 of Set 11 | mezen
# Processing Record 44 of Set 11 | wakkanai
# Processing Record 45 of Set 11 | stettler
# Processing Record 46 of Set 11 | temir
# Processing Record 47 of Set 11 | kavali
# Processing Record 48 of Set 11 | new glasgow
# Processing Record 49 of Set 11 | trincomalee
# Processing Record 50 of Set 11 | mahibadhoo
# Processing Record 1 of Set 12 | dalvik
# Processing Record 2 of Set 12 | green river
# Processing Record 3 of Set 12 | keetmanshoop
# Processing Record 4 of Set 12 | warrington
# Processing Record 5 of Set 12 | saleilua
# City not found. Skipping...
# Processing Record 6 of Set 12 | lakatoro
# Processing Record 7 of Set 12 | necochea
# Processing Record 8 of Set 12 | colares
# Processing Record 9 of Set 12 | maria aurora
# Processing Record 10 of Set 12 | bingol
# Processing Record 11 of Set 12 | kidal
# Processing Record 12 of Set 12 | georgetown
# Processing Record 13 of Set 12 | sao miguel do araguaia
# Processing Record 14 of Set 12 | kushmurun
# Processing Record 15 of Set 12 | flin flon
# Processing Record 16 of Set 12 | mount isa
# Processing Record 17 of Set 12 | helena
# Processing Record 18 of Set 12 | catalina
# Processing Record 19 of Set 12 | bicske
# Processing Record 20 of Set 12 | argelia
# Processing Record 21 of Set 12 | rantauprapat
# Processing Record 22 of Set 12 | pavilosta
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | qinzhou
# Processing Record 26 of Set 12 | khani
# Processing Record 27 of Set 12 | kazachinskoye
# Processing Record 28 of Set 12 | honiara
# Processing Record 29 of Set 12 | ostersund
# Processing Record 30 of Set 12 | mapiripan
# Processing Record 31 of Set 12 | jumla
# Processing Record 32 of Set 12 | birpur
# Processing Record 33 of Set 12 | jimo
# Processing Record 34 of Set 12 | bay roberts
# Processing Record 35 of Set 12 | ishigaki
# Processing Record 36 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 12 | mount gambier
# Processing Record 39 of Set 12 | warwick
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | masvingo
# Processing Record 42 of Set 12 | jishou
# Processing Record 43 of Set 12 | pachino
# Processing Record 44 of Set 12 | hamilton
# Processing Record 45 of Set 12 | kyzyl-suu
# Processing Record 46 of Set 12 | belmopan
# Processing Record 47 of Set 12 | borogontsy
# Processing Record 48 of Set 12 | rusape
# Processing Record 49 of Set 12 | belyy yar
# Processing Record 50 of Set 12 | pasco
# Processing Record 1 of Set 13 | westport
# Processing Record 2 of Set 13 | kawalu
# Processing Record 3 of Set 13 | aswan
# Processing Record 4 of Set 13 | lata
# Processing Record 5 of Set 13 | chipiona
# Processing Record 6 of Set 13 | rozkishne
# Processing Record 7 of Set 13 | iroquois falls
# Processing Record 8 of Set 13 | batticaloa
# Processing Record 9 of Set 13 | sao joao da barra
# Processing Record 10 of Set 13 | kargasok
# Processing Record 11 of Set 13 | okhotsk
# Processing Record 12 of Set 13 | lugus
# Processing Record 13 of Set 13 | palora
# Processing Record 14 of Set 13 | vestmanna
# Processing Record 15 of Set 13 | cacoal
# Processing Record 16 of Set 13 | guanare
# Processing Record 17 of Set 13 | yeppoon
# Processing Record 18 of Set 13 | dubrovka
# Processing Record 19 of Set 13 | rapid valley
# Processing Record 20 of Set 13 | ngunguru
# Processing Record 21 of Set 13 | popondetta
# Processing Record 22 of Set 13 | tongliao
# Processing Record 23 of Set 13 | high rock
# Processing Record 24 of Set 13 | bubaque
# Processing Record 25 of Set 13 | berlevag
# Processing Record 26 of Set 13 | sumbe
# Processing Record 27 of Set 13 | dire
# Processing Record 28 of Set 13 | deer lake
# Processing Record 29 of Set 13 | nelson bay
# Processing Record 30 of Set 13 | leshukonskoye
# Processing Record 31 of Set 13 | elbistan
# Processing Record 32 of Set 13 | ketchikan
# Processing Record 33 of Set 13 | krivosheino
# Processing Record 34 of Set 13 | baran
# Processing Record 35 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 13 | luba
# Processing Record 37 of Set 13 | harper
# Processing Record 38 of Set 13 | hami
# Processing Record 39 of Set 13 | tuy hoa
# Processing Record 40 of Set 13 | cabedelo
# Processing Record 41 of Set 13 | te anau
# Processing Record 42 of Set 13 | manggar
# Processing Record 43 of Set 13 | soe
# Processing Record 44 of Set 13 | vila franca do campo
# Processing Record 45 of Set 13 | sioux lookout
# Processing Record 46 of Set 13 | singkang
# Processing Record 47 of Set 13 | lamar
# Processing Record 48 of Set 13 | kutum
# Processing Record 49 of Set 13 | kukushtan
# Processing Record 50 of Set 13 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 14 | kotka
# Processing Record 2 of Set 14 | sinjai
# Processing Record 3 of Set 14 | san buenaventura
# Processing Record 4 of Set 14 | mizque
# Processing Record 5 of Set 14 | kalangala
# Processing Record 6 of Set 14 | amiens
# Processing Record 7 of Set 14 | asau
# Processing Record 8 of Set 14 | powell river
# Processing Record 9 of Set 14 | isa khel
# Processing Record 10 of Set 14 | kusatsu
# Processing Record 11 of Set 14 | yerbogachen
# Processing Record 12 of Set 14 | guarapari
# Processing Record 13 of Set 14 | karaj
# Processing Record 14 of Set 14 | portland
# Processing Record 15 of Set 14 | santa rosa
# Processing Record 16 of Set 14 | mishawaka
# Processing Record 17 of Set 14 | naftah
# City not found. Skipping...
# Processing Record 18 of Set 14 | palmer
# Processing Record 19 of Set 14 | karratha
# Processing Record 20 of Set 14 | bayangol
# Processing Record 21 of Set 14 | tebingtinggi
# Processing Record 22 of Set 14 | kitimat
# Processing Record 23 of Set 14 | limon
# Processing Record 24 of Set 14 | saint-leu
# Processing Record 25 of Set 14 | yarkovo
# Processing Record 26 of Set 14 | sanming
# Processing Record 27 of Set 14 | gornopravdinsk
# Processing Record 28 of Set 14 | stepnyak
# Processing Record 29 of Set 14 | spokane
# Processing Record 30 of Set 14 | havelock
# Processing Record 31 of Set 14 | qinhuangdao
# Processing Record 32 of Set 14 | polunochnoye
# Processing Record 33 of Set 14 | sawakin
# Processing Record 34 of Set 14 | ichnya
# Processing Record 35 of Set 14 | hastings
# Processing Record 36 of Set 14 | mawlaik
# Processing Record 37 of Set 14 | hovd
# Processing Record 38 of Set 14 | mbandaka
# Processing Record 39 of Set 14 | ouegoa
# Processing Record 40 of Set 14 | dalby
# Processing Record 41 of Set 14 | charters towers
# Processing Record 42 of Set 14 | itarema
# Processing Record 43 of Set 14 | novaya malykla
# Processing Record 44 of Set 14 | dong hoi
# Processing Record 45 of Set 14 | dhidhdhoo
# Processing Record 46 of Set 14 | pozo colorado
# Processing Record 47 of Set 14 | kamenka
# Processing Record 48 of Set 14 | obregon
# Processing Record 49 of Set 14 | sidi ali
# Processing Record 50 of Set 14 | port keats
# Processing Record 1 of Set 15 | mweka
# Processing Record 2 of Set 15 | port-gentil
# Processing Record 3 of Set 15 | mecca
# Processing Record 4 of Set 15 | lushunkou
# City not found. Skipping...
# Processing Record 5 of Set 15 | sosnogorsk
# Processing Record 6 of Set 15 | subkhankulovo
# Processing Record 7 of Set 15 | shache
# Processing Record 8 of Set 15 | miyang
# Processing Record 9 of Set 15 | ilhabela
# Processing Record 10 of Set 15 | vary
# Processing Record 11 of Set 15 | salym
# Processing Record 12 of Set 15 | sar-e pul
# Processing Record 13 of Set 15 | dalbandin
# Processing Record 14 of Set 15 | birobidzhan
# Processing Record 15 of Set 15 | wolmaranstad
# City not found. Skipping...
# Processing Record 16 of Set 15 | noumea
# Processing Record 17 of Set 15 | mattru
# Processing Record 18 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 19 of Set 15 | qitaihe
# Processing Record 20 of Set 15 | sur
# Processing Record 21 of Set 15 | manaure
# Processing Record 22 of Set 15 | beidao
# Processing Record 23 of Set 15 | garm
# City not found. Skipping...
# Processing Record 24 of Set 15 | surt
# Processing Record 25 of Set 15 | riyadh
# Processing Record 26 of Set 15 | cap malheureux
# Processing Record 27 of Set 15 | tatarskaya pishlya
# Processing Record 28 of Set 15 | okato
# Processing Record 29 of Set 15 | schmalkalden
# Processing Record 30 of Set 15 | qasigiannguit
# Processing Record 31 of Set 15 | sambava
# Processing Record 32 of Set 15 | kuvandyk
# Processing Record 33 of Set 15 | kashi
# Processing Record 34 of Set 15 | mayor pablo lagerenza
# Processing Record 35 of Set 15 | wawa
# Processing Record 36 of Set 15 | seredka
# Processing Record 37 of Set 15 | batemans bay
# Processing Record 38 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 15 | llanes
# Processing Record 40 of Set 15 | svetlogorsk
# Processing Record 41 of Set 15 | sheboygan
# Processing Record 42 of Set 15 | hohhot
# Processing Record 43 of Set 15 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 15 | pangkalanbuun
# Processing Record 45 of Set 15 | badaojiang
# City not found. Skipping...
# Processing Record 46 of Set 15 | elat
# Processing Record 47 of Set 15 | nushki
# Processing Record 48 of Set 15 | dawei
# Processing Record 49 of Set 15 | viedma
# Processing Record 50 of Set 15 | tarakan
# Processing Record 1 of Set 16 | oistins
# Processing Record 2 of Set 16 | monze
# Processing Record 3 of Set 16 | bulgan
# Processing Record 4 of Set 16 | santana do livramento
# Processing Record 5 of Set 16 | benjamin constant
# Processing Record 6 of Set 16 | irbil
# Processing Record 7 of Set 16 | kakonko
# Processing Record 8 of Set 16 | mahon
# Processing Record 9 of Set 16 | novomykolayivka
# Processing Record 10 of Set 16 | cayenne
# Processing Record 11 of Set 16 | farah
# Processing Record 12 of Set 16 | paracuru
# Processing Record 13 of Set 16 | bonthe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Along      IN  28.1667   94.7667     73.40        83          91
# 1      Tabory      RU  58.5198   64.5495     43.83        77         100
# 2     Rikitea      PF -23.1203 -134.9692     75.06        79          12
# 3       Avera      US  33.1940  -82.5271     80.47        50           1
# 4   Kathmandu      NP  27.7167   85.3167     66.42       100          75
# 5      Atuona      PF  -9.8000 -139.0333     78.12        77          36
# 6    Skjervoy      NO  70.0311   20.9714     41.83        80         100
# 7       Moree      AU -29.4667  149.8500     55.42        71          15
# 8     Corinto      GR  37.9407   22.9573     67.68        82           7
# 9  Cuauhtemoc      MX  28.4167 -106.8667     65.71        42          97
#
#    Wind Speed       Description
# 0        1.83   overcast clouds
# 1        6.78   overcast clouds
# 2       10.11        light rain
# 3       16.49         clear sky
# 4        3.44     broken clouds
# 5       18.34  scattered clouds
# 6       17.36   overcast clouds
# 7        4.61        few clouds
# 8        4.88         clear sky
# 9       14.47   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
